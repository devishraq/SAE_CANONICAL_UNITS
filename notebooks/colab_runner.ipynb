# %% [markdown]
# ## Setup

# %%
import torch
import sys
import os

print("Cloning repository...")
# !git clone https://github.com/devishraq/sae_canonical_units.git
# %cd /content/{sae_canonical_units}

print("\nInstalling dependencies...")
# !pip install -q -r requirements.txt
# !pip install -q -e .

sys.path.append('/content/' + 'sae_canonical_units')

print("\nSetup complete! Ready to run experiments!!!!")


if torch.cuda.is_available():
    gpu_name = torch.cuda.get_device_name(0)
    vram = torch.cuda.get_device_properties(0).total_memory / (1024**3)
    print(f"❖ GPU Active: {gpu_name}")
    print(f"❖ Total VRAM: {vram:.1f} GB")
else:
    print("GPU not active. Go to Runtime -> Change runtime type -> T4 GPU.")

# %% [markdown]
# ## Experiment Runner

# %%
# !python scripts/run_reproduction.py
